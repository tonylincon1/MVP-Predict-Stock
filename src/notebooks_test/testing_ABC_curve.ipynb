# %% [markdown]
# # Importando bibliotecas

# %%
import pandas as pd

# %% [markdown]
# # Criando classe para carregar/salvar/deletar dados
# OBS: Estou fazendo com csv, porém essa classe provavelmente irá mudar quando fizermos integrações com os bancos dos clientes.

# %%
class conect_data:
    
    def load_table(location_table, name_table, type_table,encoding='ISO-8859-1',sep=';'):
        data = pd.read_csv(f'{location_table}/{name_table}.{type_table}', encoding=encoding, sep=sep)
        return data
    
    def save_table(location_table, name_table, type_table):
        data = pd.to_csv(f'{location_table}/{name_table}.{type_table}')
        return data
    
    def del_table():
        pass

# %%
conect_data.load_table('../../data/data_ingestion/', 'ingestion.itens_describe', 'csv')
# Out:
#        NUMERO_REGISTRO_PRODUTO  IDENTIFICADOR_DO_ITEM  \
# 0                    104540166            25000025416
# 1                    119350001            25010171858
# 2                    100470305            25351022805
# 3                    104730021            25025007821
# 4                    131750004            25351032631
# ...                        ...                    ...
# 29833                100850243            25351062205
# 29834                100849958            25351365186
# 29835                138400003            25351439741
# 29836                101800412            25351726949
# 29837                135170067            25351564399
#
#                               NOME_PRODUTO TIPO_PRODUTO CATEGORIA_REGULATORIA  \
# 0          (VITAMINAS A )  +  ASSSOCIACÕES  MEDICAMENTO               SIMILAR
# 1       AC SALICILICO + AC BENZOICO + IODO  MEDICAMENTO               SIMILAR
# 2                       ALENDRONATO SODICO  MEDICAMENTO               SIMILAR
# 3                           ARNICA MONTANA  MEDICAMENTO          FITOTERÁPICO
# 4                        ARNICA MONTANA L.  MEDICAMENTO          FITOTERÁPICO
# ...                                    ...          ...                   ...
# 29833                            BDEXBRAUN  MEDICAMENTO               SIMILAR
# 29834                               NACFLU  MEDICAMENTO               SIMILAR
# 29835                              ORFADIN  MEDICAMENTO                  NOVO
# 29836                             POMALYST  MEDICAMENTO                  NOVO
# 29837                           ibuprofeno  MEDICAMENTO              GENÉRICO
#
#                                       CLASSE_TERAPEUTICA
# 0                       VITAMINAS E SUPLEMENTOS MINERAIS
# 1                          ANTIMICOTICOS PARA USO TOPICO
# 2                        SUPRESSORES DA REABSORCAO OSSEA
# 3                                   FITOTERAPICO SIMPLES
# 4                                   FITOTERAPICO SIMPLES
# ...                                                  ...
# 29833                                         HIPNOTICOS
# 29834              EXPECTORANTES BALSAMICOS E MUCOLITICO
# 29835  OUTROS PRODUTOS PARA O TRATO ALIMENTAR E METAB...
# 29836                              AGENTE IMUNOSUPRESSOR
# 29837                         ANALGESICOS NAO NARCOTICOS
#
# [29838 rows x 6 columns]

# %%
conect_data.load_table('../../data/data_ingestion/', 'ingestion.itens_input', 'csv')
# Out:
#        NUMERO_REGISTRO_PRODUTO  IDENTIFICADOR_DO_ITEM  \
# 0                    104540166            25000025416
# 1                    119350001            25010171858
# 2                    100470305            25351022805
# 3                    104730021            25025007821
# 4                    131750004            25351032631
# ...                        ...                    ...
# 29833                100850243            25351062205
# 29834                100849958            25351365186
# 29835                138400003            25351439741
# 29836                101800412            25351726949
# 29837                135170067            25351564399
#
#                               NOME_PRODUTO  DATA_DE_PEDIDO_DO_ITEM  \
# 0          (VITAMINAS A )  +  ASSSOCIACÕES                     NaN
# 1       AC SALICILICO + AC BENZOICO + IODO                     NaN
# 2                       ALENDRONATO SODICO                     NaN
# 3                           ARNICA MONTANA                     NaN
# 4                        ARNICA MONTANA L.                     NaN
# ...                                    ...                     ...
# 29833                            BDEXBRAUN                     NaN
# 29834                               NACFLU                     NaN
# 29835                              ORFADIN                     NaN
# 29836                             POMALYST                     NaN
# 29837                           ibuprofeno                     NaN
#
#       DATA_DE_ENTRADA_DO_ITEM DATA_VENCIMENTO_REGISTRO  QUANTIDADE  \
# 0                  25/04/2000               01/04/2005         NaN
# 1                  19/05/2000               01/05/2005         NaN
# 2                  04/06/2001               01/05/2006         NaN
# 3                  19/03/2002               01/03/2007         NaN
# 4                  01/07/2002               01/06/2007         NaN
# ...                       ...                      ...         ...
# 29833              29/07/2022                      NaN         NaN
# 29834              29/07/2022               01/07/2032         NaN
# 29835              29/07/2022                      NaN         NaN
# 29836              29/07/2022                      NaN         NaN
# 29837              29/07/2022                      NaN         NaN
#
#        CUSTO_DE_AQUISIÇÃO
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 29833                 NaN
# 29834                 NaN
# 29835                 NaN
# 29836                 NaN
# 29837                 NaN
#
# [29838 rows x 8 columns]

# %% [markdown]
# # Criando cálculo de classificação da curva ABC

# %% [markdown]
# # Definindo classe do cálculo da curva ABC
